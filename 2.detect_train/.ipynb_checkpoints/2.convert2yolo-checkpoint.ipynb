# %%
# 使用yolov8模型自动标注数据集（需要后续用labelimg手动标注）

# %%
from ultralytics import YOLO
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
import glob
import shutil
import tqdm

# %%
# 加载模型
model_file = "./weights/yolov8x.pt" # 模型文件
model = YOLO(model_file)  # load a pretrained model (recommended for training)
objs_labels = model.names  # get class labels
print(objs_labels)
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}

# %%
# iterate all videos
import glob
import os
import tqdm

# %%
# iterate all images
images_list = glob.glob("./images/*.jpg")

# %%
len(images_list)
# Out:
# 200

# %%
images_list[:10]
# Out:
# ['./images\\D02_20230707102139_1000.jpg',
#  './images\\D02_20230707102139_1050.jpg',
#  './images\\D02_20230707102139_1100.jpg',
#  './images\\D02_20230707102139_1150.jpg',
#  './images\\D02_20230707102139_1200.jpg',
#  './images\\D02_20230707102139_1250.jpg',
#  './images\\D02_20230707102139_1300.jpg',
#  './images\\D02_20230707102139_1350.jpg',
#  './images\\D02_20230707102139_1400.jpg',
#  './images\\D02_20230707102139_1450.jpg']

# %%
# 创建indoor_person文件夹
if not os.path.exists("./indoor_person"):
    os.mkdir("./indoor_person")

# %%
# 将图片标注为yolo格式，并保存为txt文件
def image_2_yolo():
    # 保存路径前缀
    savePathPrefix = "./indoor_person/"
    # 遍历每张图片
    for img in images_list:
        # 获取图片文件名
        imgId = img.split(os.sep)[-1].split('.')[0]
        # 读取图片
        img_data = cv2.imread(img)
        # 检测
        result = list(model(img_data, stream=True, conf=0.5))[0]  # inference，如果stream=False，返回的是一个列表，如果stream=True，返回的是一个生成器
        boxes = result.boxes  # Boxes object for bbox outputs
        boxes = boxes.cpu().numpy()  # convert to numpy array

        # 转为yolo格式：类别id、x_center y_center width height，归一化到0-1，保留6位小数
        yolo_boxes = []
        # 获取图片宽高
        img_h, img_w, _ = img_data.shape
        # 遍历每个框
        for box in boxes.data:
            l,t,r,b = box[:4].astype(np.int32) # left, top, right, bottom
            conf, id = box[4:] # confidence, class
            # 筛选出person类别
            if id == 0:
                # print(f"l: {l}, t: {t}, r: {r}, b: {b}, conf: {conf}, id: {id}")
                # if id == 0: # person, create yolo format label file
                class_label = int(id)
                x_center = round((l + r) / 2 / img_w, 6)
                y_center = round((t + b) / 2 / img_h, 6)
                width = round((r - l) / img_w, 6)
                height = round((b - t) / img_h, 6)
                
                yolo_boxes.append([class_label, x_center, y_center, width, height])

        # 写入txt文件
        # 生成yolo格式的标注文件，类似：./person_data/labels/train/000001.txt
        yoloLabelFile = savePathPrefix + imgId + '.txt'
        with open(yoloLabelFile, 'w') as f:
            for yolo_box in yolo_boxes:
                f.write(' '.join([str(i) for i in yolo_box]) + '\n')

# %%
# 启动
image_2_yolo()
# Out:
# 0: 384x640 2 persons, 115.0ms
# Speed: 4.0ms preprocess, 115.0ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.0ms
# Speed: 3.0ms preprocess, 42.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.0ms
# Speed: 2.0ms preprocess, 46.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.0ms
# Speed: 5.0ms preprocess, 45.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.0ms
# Speed: 3.0ms preprocess, 43.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 37.0ms
# Speed: 4.0ms preprocess, 37.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cell phone, 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 kite, 1 cell phone, 49.0ms
# Speed: 3.0ms preprocess, 49.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cell phone, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.0ms
# Speed: 2.0ms preprocess, 43.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.0ms
# Speed: 2.0ms preprocess, 44.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cell phone, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.0ms
# Speed: 4.0ms preprocess, 45.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cell phone, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cell phone, 39.4ms
# Speed: 2.0ms preprocess, 39.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cell phone, 47.0ms
# Speed: 3.0ms preprocess, 47.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cell phone, 48.0ms
# Speed: 6.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 54.0ms
# Speed: 3.0ms preprocess, 54.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.0ms
# Speed: 4.0ms preprocess, 45.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.0ms
# Speed: 4.0ms preprocess, 46.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 49.0ms
# Speed: 4.0ms preprocess, 49.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.0ms
# Speed: 5.0ms preprocess, 43.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.0ms
# Speed: 3.0ms preprocess, 47.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 50.0ms
# Speed: 4.0ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 42.0ms
# Speed: 3.0ms preprocess, 42.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.0ms
# Speed: 3.0ms preprocess, 45.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 33.0ms
# Speed: 6.0ms preprocess, 33.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 36.0ms
# Speed: 4.0ms preprocess, 36.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 55.5ms
# Speed: 4.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.5ms
# Speed: 5.0ms preprocess, 43.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.0ms
# Speed: 2.0ms preprocess, 43.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.0ms
# Speed: 3.0ms preprocess, 47.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 52.0ms
# Speed: 5.0ms preprocess, 52.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.0ms
# Speed: 5.0ms preprocess, 47.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.0ms
# Speed: 2.0ms preprocess, 46.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.0ms
# Speed: 3.0ms preprocess, 43.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.0ms
# Speed: 2.0ms preprocess, 46.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 41.0ms
# Speed: 5.0ms preprocess, 41.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 kite, 55.0ms
# Speed: 4.0ms preprocess, 55.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 handbag, 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.0ms
# Speed: 4.0ms preprocess, 47.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 37.0ms
# Speed: 4.0ms preprocess, 37.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.0ms
# Speed: 3.0ms preprocess, 43.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.0ms
# Speed: 6.0ms preprocess, 49.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.0ms
# Speed: 4.0ms preprocess, 52.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.0ms
# Speed: 7.0ms preprocess, 50.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.0ms
# Speed: 4.0ms preprocess, 44.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.0ms
# Speed: 4.0ms preprocess, 50.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.0ms
# Speed: 8.0ms preprocess, 48.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.0ms
# Speed: 7.0ms preprocess, 55.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.0ms
# Speed: 3.0ms preprocess, 51.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.0ms
# Speed: 4.0ms preprocess, 40.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.0ms
# Speed: 5.0ms preprocess, 50.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.0ms
# Speed: 2.0ms preprocess, 48.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 54.0ms
# Speed: 4.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 50.0ms
# Speed: 4.0ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 43.0ms
# Speed: 3.0ms preprocess, 43.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 sink, 49.0ms
# Speed: 3.0ms preprocess, 49.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 46.0ms
# Speed: 2.0ms preprocess, 46.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 47.0ms
# Speed: 3.0ms preprocess, 47.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 56.0ms
# Speed: 4.0ms preprocess, 56.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 47.0ms
# Speed: 5.0ms preprocess, 47.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 38.0ms
# Speed: 5.0ms preprocess, 38.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.0ms
# Speed: 5.0ms preprocess, 46.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 52.0ms
# Speed: 4.0ms preprocess, 52.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 50.0ms
# Speed: 5.0ms preprocess, 50.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.0ms
# Speed: 3.0ms preprocess, 43.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 46.0ms
# Speed: 4.0ms preprocess, 46.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.0ms
# Speed: 4.0ms preprocess, 47.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.0ms
# Speed: 8.0ms preprocess, 48.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.0ms
# Speed: 5.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 46.0ms
# Speed: 4.0ms preprocess, 46.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 book, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 46.0ms
# Speed: 4.0ms preprocess, 46.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.0ms
# Speed: 4.0ms preprocess, 47.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 40.0ms
# Speed: 3.0ms preprocess, 40.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 43.0ms
# Speed: 3.0ms preprocess, 43.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.0ms
# Speed: 4.0ms preprocess, 47.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 chairs, 8 tvs, 2 laptops, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 chairs, 9 tvs, 3 laptops, 1 keyboard, 47.0ms
# Speed: 3.0ms preprocess, 47.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 chairs, 10 tvs, 4 laptops, 2 keyboards, 48.0ms
# Speed: 5.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 10 tvs, 4 laptops, 2 keyboards, 46.0ms
# Speed: 8.0ms preprocess, 46.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 8 tvs, 3 laptops, 2 keyboards, 50.0ms
# Speed: 8.0ms preprocess, 50.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 8 tvs, 3 laptops, 2 keyboards, 46.0ms
# Speed: 6.0ms preprocess, 46.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 11 tvs, 4 laptops, 2 keyboards, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 11 tvs, 4 laptops, 2 keyboards, 53.0ms
# Speed: 4.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 8 tvs, 4 laptops, 1 keyboard, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 8 tvs, 4 laptops, 1 keyboard, 48.0ms
# Speed: 5.0ms preprocess, 48.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 9 tvs, 5 laptops, 2 keyboards, 45.0ms
# Speed: 3.0ms preprocess, 45.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 9 tvs, 7 laptops, 2 keyboards, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 chairs, 10 tvs, 5 laptops, 2 keyboards, 45.0ms
# Speed: 5.0ms preprocess, 45.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 chairs, 10 tvs, 5 laptops, 2 keyboards, 48.0ms
# Speed: 2.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 9 tvs, 5 laptops, 2 keyboards, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 9 tvs, 4 laptops, 2 keyboards, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 9 tvs, 2 laptops, 1 keyboard, 44.0ms
# Speed: 2.0ms preprocess, 44.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 9 tvs, 2 laptops, 2 keyboards, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 9 tvs, 3 laptops, 1 keyboard, 49.0ms
# Speed: 3.0ms preprocess, 49.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 chairs, 9 tvs, 3 laptops, 1 keyboard, 39.0ms
# Speed: 3.0ms preprocess, 39.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 chairs, 8 tvs, 4 laptops, 1 keyboard, 47.0ms
# Speed: 4.0ms preprocess, 47.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 8 tvs, 4 laptops, 2 keyboards, 49.0ms
# Speed: 5.0ms preprocess, 49.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 chairs, 8 tvs, 3 laptops, 1 keyboard, 48.0ms
# Speed: 5.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 chairs, 8 tvs, 3 laptops, 47.0ms
# Speed: 4.0ms preprocess, 47.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 chairs, 10 tvs, 4 laptops, 1 keyboard, 29.0ms
# Speed: 4.0ms preprocess, 29.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 10 tvs, 3 laptops, 1 keyboard, 49.0ms
# Speed: 3.0ms preprocess, 49.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 chairs, 9 tvs, 6 laptops, 1 keyboard, 48.0ms
# Speed: 5.0ms preprocess, 48.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 chairs, 9 tvs, 4 laptops, 1 keyboard, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 8 tvs, 3 laptops, 1 keyboard, 48.0ms
# Speed: 3.0ms preprocess, 48.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 chairs, 7 tvs, 3 laptops, 1 keyboard, 42.0ms
# Speed: 3.0ms preprocess, 42.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 8 tvs, 4 laptops, 2 keyboards, 47.0ms
# Speed: 3.0ms preprocess, 47.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 chairs, 7 tvs, 4 laptops, 2 keyboards, 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 chairs, 9 tvs, 3 laptops, 2 keyboards, 48.0ms
# Speed: 5.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 9 tvs, 2 laptops, 2 keyboards, 47.0ms
# Speed: 3.0ms preprocess, 47.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 chairs, 8 tvs, 2 laptops, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 chairs, 8 tvs, 2 laptops, 49.0ms
# Speed: 4.0ms preprocess, 49.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 chairs, 9 tvs, 3 laptops, 2 keyboards, 49.0ms
# Speed: 3.0ms preprocess, 49.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 chairs, 9 tvs, 3 laptops, 2 keyboards, 50.0ms
# Speed: 4.0ms preprocess, 50.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 chairs, 9 tvs, 4 laptops, 2 keyboards, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 chairs, 7 tvs, 5 laptops, 2 keyboards, 41.0ms
# Speed: 4.0ms preprocess, 41.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 10 tvs, 2 laptops, 2 keyboards, 46.0ms
# Speed: 2.0ms preprocess, 46.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 chairs, 9 tvs, 2 keyboards, 52.0ms
# Speed: 7.0ms preprocess, 52.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 10 tvs, 3 laptops, 1 keyboard, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 chairs, 9 tvs, 5 laptops, 1 keyboard, 44.0ms
# Speed: 4.0ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 chairs, 9 tvs, 4 laptops, 45.0ms
# Speed: 3.0ms preprocess, 45.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 chairs, 11 tvs, 4 laptops, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 7 tvs, 3 laptops, 41.0ms
# Speed: 4.0ms preprocess, 41.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 chairs, 8 tvs, 3 laptops, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 7 tvs, 4 laptops, 48.0ms
# Speed: 5.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 chairs, 7 tvs, 4 laptops, 48.0ms
# Speed: 6.0ms preprocess, 48.0ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 chairs, 7 tvs, 3 laptops, 46.0ms
# Speed: 4.0ms preprocess, 46.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 chairs, 6 tvs, 4 laptops, 38.0ms
# Speed: 4.0ms preprocess, 38.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 chairs, 9 tvs, 3 laptops, 41.0ms
# Speed: 3.0ms preprocess, 41.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 chairs, 9 tvs, 4 laptops, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 chairs, 7 tvs, 4 laptops, 47.0ms
# Speed: 4.0ms preprocess, 47.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 chairs, 7 tvs, 4 laptops, 47.0ms
# Speed: 6.0ms preprocess, 47.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 chairs, 8 tvs, 4 laptops, 1 keyboard, 50.0ms
# Speed: 5.0ms preprocess, 50.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 chairs, 7 tvs, 4 laptops, 1 keyboard, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 7 tvs, 3 laptops, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 chairs, 8 tvs, 4 laptops, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 chairs, 7 tvs, 4 laptops, 46.0ms
# Speed: 5.0ms preprocess, 46.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 7 tvs, 4 laptops, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 7 tvs, 4 laptops, 49.0ms
# Speed: 5.0ms preprocess, 49.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 chairs, 7 tvs, 4 laptops, 39.0ms
# Speed: 3.0ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 chairs, 7 tvs, 3 laptops, 39.0ms
# Speed: 3.0ms preprocess, 39.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 chairs, 7 tvs, 4 laptops, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 chairs, 8 tvs, 4 laptops, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 8 tvs, 4 laptops, 54.0ms
# Speed: 3.0ms preprocess, 54.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 chairs, 7 tvs, 4 laptops, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 chairs, 7 tvs, 3 laptops, 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 8 tvs, 5 laptops, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 7 tvs, 5 laptops, 48.0ms
# Speed: 3.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 chairs, 7 tvs, 4 laptops, 1 keyboard, 51.0ms
# Speed: 3.0ms preprocess, 51.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 chairs, 7 tvs, 4 laptops, 1 keyboard, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 8 tvs, 5 laptops, 50.0ms
# Speed: 4.0ms preprocess, 50.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 chairs, 8 tvs, 5 laptops, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 chairs, 7 tvs, 4 laptops, 49.0ms
# Speed: 3.0ms preprocess, 49.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 chairs, 7 tvs, 4 laptops, 30.0ms
# Speed: 2.0ms preprocess, 30.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 chairs, 6 tvs, 5 laptops, 46.0ms
# Speed: 4.0ms preprocess, 46.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 6 tvs, 5 laptops, 45.0ms
# Speed: 6.0ms preprocess, 45.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 6 tvs, 5 laptops, 35.0ms
# Speed: 4.0ms preprocess, 35.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 7 tvs, 5 laptops, 44.0ms
# Speed: 6.0ms preprocess, 44.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 chairs, 6 tvs, 5 laptops, 47.0ms
# Speed: 7.0ms preprocess, 47.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 chairs, 6 tvs, 5 laptops, 46.0ms
# Speed: 2.0ms preprocess, 46.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 chairs, 9 tvs, 2 laptops, 2 keyboards, 37.0ms
# Speed: 4.0ms preprocess, 37.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 chairs, 8 tvs, 1 laptop, 2 keyboards, 53.0ms
# Speed: 5.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 chairs, 6 tvs, 1 laptop, 2 keyboards, 47.0ms
# Speed: 3.0ms preprocess, 47.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 chairs, 7 tvs, 2 laptops, 2 keyboards, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 chairs, 10 tvs, 1 keyboard, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 chairs, 12 tvs, 1 keyboard, 43.0ms
# Speed: 2.0ms preprocess, 43.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 chairs, 10 tvs, 1 laptop, 2 keyboards, 48.0ms
# Speed: 3.0ms preprocess, 48.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 9 tvs, 2 laptops, 2 keyboards, 44.0ms
# Speed: 2.0ms preprocess, 44.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 11 tvs, 2 laptops, 2 keyboards, 52.0ms
# Speed: 4.0ms preprocess, 52.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 chairs, 10 tvs, 1 laptop, 2 keyboards, 40.0ms
# Speed: 4.0ms preprocess, 40.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 chairs, 8 tvs, 4 laptops, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 chairs, 9 tvs, 3 laptops, 45.0ms
# Speed: 4.0ms preprocess, 45.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 chairs, 8 tvs, 3 laptops, 1 keyboard, 51.0ms
# Speed: 3.0ms preprocess, 51.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 chairs, 8 tvs, 6 laptops, 1 keyboard, 51.0ms
# Speed: 3.0ms preprocess, 51.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 chairs, 9 tvs, 3 laptops, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 chairs, 9 tvs, 2 laptops, 43.0ms
# Speed: 4.0ms preprocess, 43.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
# 根据yolo格式的标注文件，在图片上绘制
def yoloDraw(img, yoloLabelFile):
    '''
    @param img: 图片
    @param yoloLabelFile: yolo格式的标注文件路径
    '''
    img_copy = img.copy()
    # 生成5类标签对应的颜色
    color_dict = {0: (255, 0, 0), 1: (0, 255, 0), 2: (0, 0, 255), 3: (255, 255, 0), 4: (0, 255, 255)}
    with open(yoloLabelFile, 'r') as f:
        lines = f.readlines()
        lines = [line.strip() for line in lines]
        boxes = [line.split(' ') for line in lines]
        for box in boxes:
            class_label = int(box[0])
            x_center, y_center, width, height = [float(i) for i in box[1:]]
            x1 = int((x_center - width / 2) * img_copy.shape[1])
            y1 = int((y_center - height / 2) * img_copy.shape[0])
            x2 = int((x_center + width / 2) * img_copy.shape[1])
            y2 = int((y_center + height / 2) * img_copy.shape[0])
            cv2.rectangle(img_copy, (x1, y1), (x2, y2), color_dict[class_label], 2)
            cv2.putText(img_copy, str(class_label), (x1, y1), cv2.FONT_HERSHEY_SIMPLEX,1, color_dict[class_label], 2)
    plt.imshow(img_copy[:,:,::-1])
    plt.axis('off')
    plt.show()

# %%
# 读取并显示
imgFile = './images/D02_20230707102139_800.jpg'
img = cv2.imread(imgFile)
plt.imshow(img[:,:,::-1])
plt.axis('off')
# Out:
# (-0.5, 2303.5, 1295.5, -0.5)

# %%
# 测试显示，也可以在LabelImg中查看
yoloDraw(img, "./indoor_person/D02_20230707102139_800.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 测试显示，也可以在LabelImg中查看
# ----> 2 yoloDraw(img, "./indoor_person/D05_20230707102820_1200.txt")
#
# Cell In[10], line 10, in yoloDraw(img, yoloLabelFile)
#       8 # 生成5类标签对应的颜色
#       9 color_dict = {0: (255, 0, 0), 1: (0, 255, 0), 2: (0, 0, 255), 3: (255, 255, 0), 4: (0, 255, 255)}
# ---> 10 with open(yoloLabelFile, 'r') as f:
#      11     lines = f.readlines()
#      12     lines = [line.strip() for line in lines]
#
# File c:\conda\envs\reid_env\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './indoor_person/D05_20230707102820_1200.txt'

# %%
# 生成classes.txt，每行写入一个类别，0:person
with open('./classes.txt', 'w') as f:
    f.writelines(['0 person\n'])

# %%
# 创建多级文件路径：./person_data/images/train, ./person_data/images/val, ./person_data/labels/train, ./person_data/labels/val
if not os.path.exists('./person_data'):
    os.mkdir('./person_data')
if not os.path.exists('./person_data/images'):
    os.mkdir('./person_data/images')
if not os.path.exists('./person_data/images/train'):
    os.mkdir('./person_data/images/train')
if not os.path.exists('./person_data/images/val'):
    os.mkdir('./person_data/images/val')

if not os.path.exists('./person_data/labels'):
    os.mkdir('./person_data/labels')
if not os.path.exists('./person_data/labels/train'):
    os.mkdir('./person_data/labels/train')
if not os.path.exists('./person_data/labels/val'):
    os.mkdir('./person_data/labels/val')

# %%
label_list = glob.glob("./indoor_person/*.txt")

# %%
label_list

# %%
# 按照8:2划分训练集和验证集
train_num = int(len(images_list) * 0.8)
train_images_list = images_list[:train_num]
val_images_list = images_list[train_num:]

train_label_list = label_list[:train_num]
val_label_list = label_list[train_num:]

# %%
# 打印训练集和验证集的数量
print(f"train images num: {len(train_images_list)}, train labels num: {len(train_label_list)}")
print(f"val images num: {len(val_images_list)}, val labels num: {len(val_label_list)}")

# %%
# 处理训练集
for img_file_name in tqdm.tqdm(train_images_list, desc='train'):
    # filename
    filename = img_file_name.split(os.sep)[-1]
    # 复制图片到指定路径
    shutil.copy(img_file_name, './person_data/images/train/' + filename)
    #复制标注文件到指定路径
    label_file_name = img_file_name.split(os.sep)[-1].split('.')[0] + '.txt'
    shutil.copy('./indoor_person/' + label_file_name, './person_data/labels/train/' + label_file_name)

# 处理验证集
for img_file_name in tqdm.tqdm(val_images_list, desc='val'):
    # filename
    filename = img_file_name.split(os.sep)[-1]
    # 复制图片到指定路径
    shutil.copy(img_file_name, './person_data/images/val/' + filename)
    #复制标注文件到指定路径
    label_file_name = img_file_name.split(os.sep)[-1].split('.')[0] + '.txt'
    shutil.copy('./indoor_person/' + label_file_name, './person_data/labels/val/' + label_file_name)
